# %% [markdown]
# context: Qantas Airlines
#
# hedging instruments:
# 1. Linear (swaps and futures)
#
# 2. nonlinear (options, collars, three-ways) (too complex and will eat up the report page, put in appendix)
#
# forecast targets: ...
